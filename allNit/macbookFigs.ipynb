# %% [markdown]
# # Figures for MacBook

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-white') # One of the two of these styles will work. not sure why it changes.
#plt.style.use('seaborn-darkgrid')
print(plt.style.available)
import numpy as np
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
def flooxsRead(IVFile):
    IVFile = np.loadtxt(IVFile, delimiter=',')    
    Vds = IVFile[:,0]
    I = IVFile[:,1]
    return Vds,I

# %% [markdown]
# # Transfer Curves

# %% [markdown]
# ## Fieldplate

# %%
fieldplate_Vgs, fieldplate_Ids = flooxsRead("/Users/ianstafford/banjo-wombat/allNit/fieldplate_Vt.csv")
plt.figure(figsize=[10,10]);
plt.plot(fieldplate_Vgs, 1000*fieldplate_Ids, label="Field Plate");
plt.title("$I_{DS}$ vs $V_{GS}$ at $V_{DS}=10V$", fontsize=20);
plt.xlabel("$V_{G} (V)$", fontsize=20);
plt.ylabel("$I_{DS}$ (${mA}/{mm}$)", fontsize=20);
plt.xticks(fontsize = 18)
plt.yticks(fontsize = 18)
plt.grid(True);
#plt.legend();
#plt.savefig("Vt.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Fieldplate with gate nitride

# %%
fieldplate_ox_Vgs, fieldplate_ox_Ids = flooxsRead("/Users/ianstafford/banjo-wombat/allNit/fieldplate_ox_Vt.csv")
plt.figure(figsize=[10,10]);
plt.plot(fieldplate_ox_Vgs, 1000*fieldplate_ox_Ids, label="Field Plate with Oxide");
plt.title("$I_{DS}$ vs $V_{GS}$ at $V_{DS}=10V$", fontsize=20);
plt.xlabel("$V_{G} (V)$", fontsize=20);
plt.ylabel("$I_{DS}$ (${mA}/{mm}$)", fontsize=20);
plt.xticks(fontsize = 18)
plt.yticks(fontsize = 18)
plt.grid(True);
#plt.legend();
#plt.savefig("Vt.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Wrapped field plate structure

# %%
fieldplate_wrap_Vgs, fieldplate_wrap_Ids = flooxsRead("/Users/ianstafford/banjo-wombat/allNit/fieldplate_wrap_Vt.csv")
plt.figure(figsize=[10,10]);
plt.plot(fieldplate_wrap_Vgs, 1000*fieldplate_wrap_Ids, label="Wrapped field plate structure");
plt.title("$I_{DS}$ vs $V_{GS}$ at $V_{DS}=10V$", fontsize=20);
plt.xlabel("$V_{G} (V)$", fontsize=20);
plt.ylabel("$I_{DS}$ (${mA}/{mm}$)", fontsize=20);
plt.xticks(fontsize = 18)
plt.yticks(fontsize = 18)
plt.grid(True);
#plt.legend();
#plt.savefig("Vt.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Experimental Data

# %%
REF_Vgs, REF_Ids = flooxsRead("/Users/ianstafford/banjo-wombat/allNit/experimentalREF.csv")
RF2_Vgs, RF2_Ids = flooxsRead("/Users/ianstafford/banjo-wombat/allNit/experimentalRF2.csv")
plt.figure(figsize=[8,8]);
plt.plot(REF_Vgs, 1000*REF_Ids, label="REF");
plt.plot(RF2_Vgs, 1000*RF2_Ids, label="RF2");
#plt.plot(fieldplate_Vgs, 1000*fieldplate_Ids, label="Field Plate");
plt.plot(fieldplate_wrap_Vgs, 1000*fieldplate_wrap_Ids, label="Wrapped field plate structure");

#plt.plot(fieldplate_ox_Vgs, 1000*fieldplate_ox_Ids, label="Field Plate with Oxide");
plt.title("$I_{DS}$ vs $V_{GS}$ at $V_{DS}=10V$", fontsize=20);
plt.xlabel("$V_{G} (V)$", fontsize=20);
plt.ylabel("$I_{DS}$ (${mA}/{mm}$)", fontsize=20);
plt.xticks(fontsize = 18)
plt.yticks(fontsize = 18)
plt.grid(True);
plt.legend();
#plt.savefig("Vt.png", dpi=300, bbox_inches='tight')
plt.show()
